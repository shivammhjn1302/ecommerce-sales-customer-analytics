# %% [markdown]
# # E-Commerce Analytics Notebook\nExploratory analysis, KPI validation, segmentation, forecasting, and churn modeling workflow.

# %%
import pandas as pd\norders = pd.read_csv('../data/processed/orders_enriched.csv')\norders.head()

# %%
orders.groupby('category')['net_sales'].sum().sort_values(ascending=False)
